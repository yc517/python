# %% [markdown]
# ### 輸入股票代碼，回傳股票資料

# %%
# %matplotlib inline

import io
import requests
import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
def crawl_price(stock_id):
    now = int(datetime.datetime.now().timestamp())+186400 #讓period2到現在
    url = "https://query1.finance.yahoo.com/v7/finance/download/" + stock_id + "?period1=1541088000&period2=" + str(now) + "&interval=1d&events=history&crumb=hP2rOschxO0"

    response = requests.post(url)

    f = io.StringIO(response.text)
    df = pd.read_csv(f, index_col='Date', parse_dates=['Date'] )
    df = df.drop('Volume', axis = 1)
    
    ma_list = [5, 20, 60]
    for ma in ma_list:
        df['MA_' + str(ma)] = df['Adj Close'].rolling(ma).mean()
    
    return df

# %%
ham = input('請輸入想搜尋的股票代碼：')
# Out:
# 請輸入想搜尋的股票代碼：2330

# %%
df = crawl_price(str(ham) + '.TW')
stock = '台股 ' + str(ham)
print(stock)
df.loc[:, 'Close': 'MA_60'].plot();
# Out:
# 台股 2330
